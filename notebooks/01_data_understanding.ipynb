# %% [markdown]
# E-Commerce Sales & Customer Analytics Dashboard
# Phase 1: Data Understanding
# Objective
# The purpose of this notebook is to understand the dataset before performing any analysis.
# In this notebook, we will:
# - Load the dataset
# - View the first few records
# - Check the number of rows and columns
# - Display column names
# - Understand data types
# - Check for missing values
# - Generate summary statistics
# Tools Used
# - Python
# - Pandas
# - NumPy
# - Jupyter Notebook

# %%
# Import the Pandas library for data manipulation
import pandas as pd

# Import the NumPy library for numerical operations
import numpy as np

print("Libraries loaded successfully!")
# Out:
# Libraries loaded successfully!

# %% [markdown]
# ## Loading the Dataset
#
# The dataset is stored inside the **data** folder.
#
# We use the `read_excel()` function provided by the Pandas library to load the Excel file into a DataFrame.

# %%
# Load the Excel dataset

df = pd.read_excel("../data/sample_-_superstore.xls")

# Display the first five rows

df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  US-2023-103800 2023-01-03 2023-01-07  Standard Class    DP-13000
# 1       2  US-2023-112326 2023-01-04 2023-01-08  Standard Class    PO-19195
# 2       3  US-2023-112326 2023-01-04 2023-01-08  Standard Class    PO-19195
# 3       4  US-2023-112326 2023-01-04 2023-01-08  Standard Class    PO-19195
# 4       5  US-2023-141817 2023-01-05 2023-01-12  Standard Class    MB-18085
#
#    Customer Name      Segment Country/Region          City  ... Postal Code  \
# 0  Darren Powers     Consumer  United States       Houston  ...       77095
# 1  Phillina Ober  Home Office  United States    Naperville  ...       60540
# 2  Phillina Ober  Home Office  United States    Naperville  ...       60540
# 3  Phillina Ober  Home Office  United States    Naperville  ...       60540
# 4     Mick Brown     Consumer  United States  Philadelphia  ...       19143
#
# ...

# %% [markdown]
# ## Dataset Shape
#
# The `shape` attribute returns the total number of rows and columns in the dataset.

# %%
# Display the number of rows and columns

print("Dataset Shape:", df.shape)
# Out:
# Dataset Shape: (10194, 21)

# %% [markdown]
# ## Column Names
#
# The dataset contains multiple columns representing customer details, order information, sales, profit, and shipping details.
#
# The `columns` attribute displays all column names.

# %%
# Display all column names

df.columns.tolist()
# Out:
# ['Row ID',
#  'Order ID',
#  'Order Date',
#  'Ship Date',
#  'Ship Mode',
#  'Customer ID',
#  'Customer Name',
#  'Segment',
#  'Country/Region',
#  'City',
#  'State/Province',
#  'Postal Code',
#  'Region',
#  'Product ID',
#  'Category',
#  'Sub-Category',
#  'Product Name',
#  'Sales',
#  'Quantity',
#  'Discount',
#  'Profit']

# %% [markdown]
# ## Dataset Information
#
# The `info()` method provides information about:
#
# - Number of rows
# - Number of columns
# - Data types
# - Non-null values
# - Memory usage

# %%
# Display dataset information

df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10194 entries, 0 to 10193
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          10194 non-null  int64
#  1   Order ID        10194 non-null  str
#  2   Order Date      10194 non-null  datetime64[us]
#  3   Ship Date       10194 non-null  datetime64[us]
#  4   Ship Mode       10194 non-null  str
#  5   Customer ID     10194 non-null  str
#  6   Customer Name   10194 non-null  str
#  7   Segment         10194 non-null  str
#  8   Country/Region  10194 non-null  str
#  9   City            10194 non-null  str
#  10  State/Province  10194 non-null  str
#  11  Postal Code     10194 non-null  object
#  12  Region          10194 non-null  str
#  13  Product ID      10194 non-null  str
#  14  Category        10194 non-null  str
#  15  Sub-Category    10194 non-null  str
#  16  Product Name    10194 non-null  str
#  17  Sales           10194 non-null  float64
# ...

# %% [markdown]
# ## Missing Values
#
# Missing values can affect analysis and machine learning models.
#
# We use `isnull().sum()` to count missing values in each column.

# %%
# Check missing values

df.isnull().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country/Region    0
# City              0
# State/Province    0
# Postal Code       0
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# Quantity          0
# Discount          0
# Profit            0
# dtype: int64

# %% [markdown]
# ## Summary Statistics
#
# The `describe()` function generates statistical information for all numerical columns, including:
#
# - Count
# - Mean
# - Standard Deviation
# - Minimum
# - Maximum
# - Quartiles

# %%
# Generate summary statistics

df.describe()
# Out:
#              Row ID                  Order Date                   Ship Date  \
# count  10194.000000                       10194                       10194
# mean    5097.500000  2025-04-29 11:48:25.002943  2025-05-03 10:52:45.626839
# min        1.000000         2023-01-03 00:00:00         2023-01-07 00:00:00
# 25%     2549.250000         2024-05-14 00:00:00         2024-05-19 00:00:00
# 50%     5097.500000         2025-06-25 00:00:00         2025-06-28 00:00:00
# 75%     7645.750000         2026-05-14 00:00:00         2026-05-18 00:00:00
# max    10194.000000         2026-12-30 00:00:00         2027-01-05 00:00:00
# std     2942.898656                         NaN                         NaN
#
#               Sales      Quantity      Discount        Profit
# count  10194.000000  10194.000000  10194.000000  10194.000000
# mean     228.225854      3.791838      0.155385     28.673417
# min        0.444000      1.000000      0.000000  -6599.978000
# ...
